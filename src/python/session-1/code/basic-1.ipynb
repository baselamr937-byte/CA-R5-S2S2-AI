# %%
x=5 
print(x)
# Out:
# 5

# %%
name="Basel"
age=30
course="machine learning"
message=f"your name is {name}, you are {age} years old and you are learning {course}"
print(message)
# Out:
# your name is Basel, you are 30 years old and you are learning machine learning
