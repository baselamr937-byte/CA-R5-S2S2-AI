# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
list_1 = [1,2,3,4,"Depi", "learning",True,[1,2,3,["ML", "AI","GenAI"]]]
list_1[7][3][1]
# Out:
# 'AI'

# %%
list_2=["depo","pro","bro"]
list_2.append("last item")
print(list_2)

list_2.insert(2,"middle item")
print(list_2)

list_3=["repo","not","dot"]
list_2.extend(list_3)
print(list_2)

list_2.extend("ahmed")
print(list_2)

x=list_3.pop()
print(f"{x} - {list_3}")
# Out:
# ['depo', 'pro', 'bro', 'last item']
# ['depo', 'pro', 'middle item', 'bro', 'last item']
# ['depo', 'pro', 'middle item', 'bro', 'last item', 'repo', 'not', 'dot']
# ['depo', 'pro', 'middle item', 'bro', 'last item', 'repo', 'not', 'dot', 'a', 'h', 'm', 'e', 'd']
# dot - ['repo', 'not']

# %%
item= input("Enter item to remove: ")

list_1 = ["Depi","learning","ml","learning"]
if item in list_1:
    list_1.remove(item)
    print(f"{item} removed from the list.")
    print(list_1)
else:
    print("Item not found in the list.")
# Out:
# Depi removed from the list.
# ['learning', 'ml', 'learning']

# %%
item= input("Enter item to remove: ")

list_1 = ["Depi","learning","ml","learning"]

list_1.remove(item)
print(list_1)
# Out:
# ['learning', 'ml', 'learning']

# %%
list_1 = ["ss","Depi", "learning"]
list_1.sort()
print(list_1)
# Out:
# ['Depi', 'learning', 'ss']

# %%
input="ml"
tuple_1 = ("Depi","learning",input)
print(tuple_1)

list(tuple_1)

# %%
a=input("Enter your first number: ")
b=input("Enter your second number: ")
c=float(a)+float(b)
d=float(a)-float(b)
e=float(a)*float(b)
f=float(a)/float(b)
print(f"Sum: {c}, Subtraction: {d}, Multiplication: {e}, Division: {f}")
# Out:
# Sum: 18.0, Subtraction: 6.0, Multiplication: 72.0, Division: 2.0

# %%
grade=float(input("Enter your grade: "))
if 100>grade>90:
    print("A")
elif 90>grade>80:
    print("B")
elif 80>grade>70:
    print("C")
elif 70>grade>60:
    print("D")
else:
    print("F")
# Out:
# B
