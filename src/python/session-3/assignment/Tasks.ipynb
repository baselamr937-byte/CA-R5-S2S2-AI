# %% [markdown]
# ### Task 1

# %%
def multiplication_table(num:(int)=2)->str:
    ''' 
    this function takes a number and prints the multiplication table for it using a for loop 

    parameters:
            takes an integar parameter with an intial value of 2 
    return:
            print a strings value of the multiplication tabel 
        
    
    '''
    for i in range(1, 13):
        
        multi= num*i
        statement= f"{num} * {i}={multi}"
        print(statement)
    
    
        
        
multiplication_table(6)
# Out:
# 6 * 1=6
# 6 * 2=12
# 6 * 3=18
# 6 * 4=24
# 6 * 5=30
# 6 * 6=36
# 6 * 7=42
# 6 * 8=48
# 6 * 9=54
# 6 * 10=60
# 6 * 11=66
# 6 * 12=72

# %% [markdown]
# ### Task 2

# %%
import math
''' 





'''
print("Twin Primes:")
for i in range(3, 1000, 2):
    
    for x in range(round(int(i/2))):
        first_pr=False
        if x==0 or x==1:
            continue
        if i%x==0:
            first_pr=True
            break
    for x in range(round(int((i+2)/2))):
        second_prime=False
        if x==0 or x==1:
            continue
        if (i+2)%x==0:
            second_prime=True
            break
    if first_pr==False and second_prime==False:
        print(f"{i} and {i+2}")
# Out:
# Twin Primes:
# 3 and 5
# 5 and 7
# 11 and 13
# 17 and 19
# 29 and 31
# 41 and 43
# 59 and 61
# 71 and 73
# 101 and 103
# 107 and 109
# 137 and 139
# 149 and 151
# 179 and 181
# 191 and 193
# 197 and 199
# 227 and 229
# 239 and 241
# 269 and 271
# 281 and 283
# 311 and 313
# 347 and 349
# 419 and 421
# 431 and 433
# 461 and 463
# 521 and 523
# 569 and 571
# 599 and 601
# 617 and 619
# 641 and 643
# 659 and 661
# 809 and 811
# 821 and 823
# 827 and 829
# 857 and 859
# 881 and 883

# %% [markdown]
# ### Task 3

# %%
num=float(input("enter the number"))
first_divisable=0
for i in range(int(num/2)):
    if i==0:
        continue
    if num%i==0:
        first_divisable=i
        if first_divisable>0:
            for n in range(num/first_divisable):
                if num%n==0:
                    second_divisable=n
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 9
#       5         continue
#       6     if num%i==0:
#       7         first_divisable=i
#       8         if first_divisable>0:
# ----> 9             for n in range(num/first_divisable):
#      10                 if num%n==0:
#      11                     second_divisable=n
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# ### Task 4

# %%
def decToBin(num:int=2)->str:
    ''' 
    this function takes a number and prints the binary value for it using a while loop 

    parameters:
            takes an integar parameter with an intial value of 2 
    return:
            print a strings value of the binary value 
    '''
    bin_num=""
    while num>0:
        bin_num+=str(num%2)
        num=num//2
    print(bin_num[::-1])
    
decToBin(10)
# Out:
# 1010

# %% [markdown]
# ### Task 5
