# %% [markdown]
# #### assesment data leakage
# #### label encode vs target encode

# %% [markdown]
# ### **ML**  1-supervisied: *regression: (linear regression, evaluation , polyinomal , over fit , under fit , L1 & L2 )* ,
# ###                        *classification:logistic classification , SVM , Decision tree ,Random forest, boost*
# ### 2-unsupervised: K mean , DB scan , hiraicy structure , PCA,tsm

# %% [markdown]
# linear regression

# %% [markdown]
# ### best fit line
# ### , wx+b=y
# ### , b = bias
# ### , w= slope or theta
# ### , it has coleration (best fit line) XXXXXXXXXXX not accuray XXXXXXXXXX
# ### Probability (estimated point)

# %% [markdown]
# ### 1- wx+b=y
# ### 2-  1/n * sum of (y2-(wx+b))^2 -> dl/dw=2/n sum of (y-y2)*x or another sol 1/n *  sum of |y2-y1|
# ### 3- w= w- alpha * dE/dw    (gradient decent)

# %%
import matplotlib as pt
